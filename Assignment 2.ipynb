# %% [markdown]
# ## Importing the Packages

# %%
# Importing Pandas Package.
import pandas as pd

# %% [markdown]
# ## Reading the Dataset

# %%
# Storing the Dataset into a File and Reading that Dataset with pandas
file="C:/Users/prave/Downloads/amazon_prime_titles.csv.zip"
df = pd.read_csv(file)
# Printing First 20 Rows of Dataset by Head Method
df.head(20)
# Out:
#    show_id     type                              title  \
# 0       s1    Movie                The Grand Seduction
# 1       s2    Movie               Take Care Good Night
# 2       s3    Movie               Secrets of Deception
# 3       s4    Movie                 Pink: Staying True
# 4       s5    Movie                      Monster Maker
# 5       s6    Movie              Living With Dinosaurs
# 6       s7    Movie                          Hired Gun
# 7       s8    Movie                       Grease Live!
# 8       s9    Movie                    Global Meltdown
# 9      s10    Movie                     David's Mother
# 10     s11    Movie                     Forest Fairies
# 11     s12    Movie                          Take Care
# 12     s13    Movie           The Night Eats The World
# 13     s14    Movie                         Resilencia
# 14     s15    Movie  Elon Musk: The Real Life Iron Man
# 15     s16    Movie                         Summer '03
# ...

# %% [markdown]
# ## Pre-Processing the Data from Dataset

# %%
# Printing the Columns Present in Dataset
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Printing the Datatypes Present in Dataset
print(df.dtypes)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Printing the Information of Dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB
# None

# %%
# Printing the Statistical Information for Numerical Cloumns of Dataset
print(df.describe())
# Out:
#        release_year
# count   9668.000000
# mean    2008.341849
# std       18.922482
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Creating New Column named Length, to Store Length of the Text Column
df['length'] = df['description'].str.len()
df.describe()
# Out:
#        release_year       length
# count   9668.000000  9668.000000
# mean    2008.341849   253.774824
# std       18.922482   110.248775
# min     1920.000000     1.000000
# 25%     2007.000000   171.000000
# 50%     2016.000000   238.000000
# 75%     2019.000000   347.000000
# max     2021.000000  1099.000000

# %%
# Using the Describe Method
df.describe(include='O')
# Out:
#        show_id   type                title     director            cast  \
# count     9668   9668                 9668         7585            8435
# unique    9668      2                 9668         5773            7927
# top         s1  Movie  The Grand Seduction  Mark Knight  Maggie Binkley
# freq         1   7814                    1          113              56
#
#               country      date_added rating  duration listed_in  \
# count             672             155   9331      9668      9668
# unique             86              84     24       219       518
# top     United States  March 30, 2021    13+  1 Season     Drama
# freq              253              14   2117      1342       986
#
#                                               description
# count                                                9668
# unique                                               9414
# top     Arpo was designed as a commando robot, built a...
# ...

# %% [markdown]
# ## Extracting Data from Data set

# %%
# Finding Null Values in Dataset
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2083
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# length             0
# dtype: int64

# %%
# Filling NA values Column with Unknown
df['director'].fillna('unknown', inplace=True)
df['cast'].fillna('unknown', inplace=True)
df['country'].fillna('unknown', inplace=True)
df['date_added'].fillna('unknown', inplace=True)
df['rating'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# length          0
# dtype: int64

# %%
# Changing the Text Case of Columns to UpperCase
df['title'] = df['title'].str.upper()
df['director'] = df['director'].str.upper()
df['type'] = df['type'].str.lower()
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    movie      THE GRAND SEDUCTION     DON MCKELLAR
# 1         s2    movie     TAKE CARE GOOD NIGHT     GIRISH JOSHI
# 2         s3    movie     SECRETS OF DECEPTION      JOSH WEBBER
# 3         s4    movie       PINK: STAYING TRUE   SONIA ANDERSON
# 4         s5    movie            MONSTER MAKER     GILES FOSTER
# ...      ...      ...                      ...              ...
# 9663   s9664    movie      PRIDE OF THE BOWERY  JOSEPH H. LEWIS
# 9664   s9665  tv show            PLANET PATROL          UNKNOWN
# 9665   s9666    movie                  OUTPOST     STEVE BARKER
# 9666   s9667  tv show  MARADONA: BLESSED DREAM          UNKNOWN
# 9667   s9668    movie              HARRY BROWN    DANIEL BARBER
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
# Extracting BUSH instance
df[df['title'].str.contains('LIFE')]
# Out:
#      show_id     type                                             title  \
# 14       s15    movie                 ELON MUSK: THE REAL LIFE IRON MAN
# 25       s26    movie                            ZAMBEZI: FORCE OF LIFE
# 317     s318  tv show                                 TOCA LIFE STORIES
# 456     s457    movie                   THE SECRET LIFE OF WALTER MITTY
# 457     s458  tv show                             THE SECRET LIFE OF US
# ...      ...      ...                                               ...
# 9167   s9168    movie        LARA CROFT TOMB RAIDER: THE CRADLE OF LIFE
# 9173   s9174    movie                    JAY STEVENS: LIFE IS HILARIOUS
# 9176   s9177    movie                        IT'S A WONDERFUL AFTERLIFE
# 9241   s9242    movie                     BT: MY LIFE AS I KNOW IT NOW!
# 9564   s9565    movie  A-TEAM: LIFE AFTER FILM SCHOOL WITH JOE CARNAHAN
#
#                 director                                               cast  \
# ...

# %% [markdown]
# ## Data Visuailazation

# %%
# Importing matplotlib Package
import matplotlib.pyplot as plt

# Taking 'length' as Target Column
df['length'].plot(label='Length')
plt.xlabel('Index')
plt.ylabel('Length')
# Adding legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ## Box-Plot

# %%
# Ploting a Box Plot
df['length'].plot(kind='box')

# Adding x and y axis labels
plt.xlabel('Length')
plt.ylabel('')

# Display the plot
plt.show()

# %% [markdown]
# ## Histogram

# %%
# Drawing a Histogram
df['length'].plot(kind='hist', bins=25)

# Adding x and y axis labels, legend 
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.legend()
# Display the plot
plt.show()

# %%
# Importing Seaborn Package
import seaborn as sns
where = df['rating'].isin(['R', 'PG', 'G', 'TV-14', 'PG-13'])
g = sns.catplot(data=df[where], x="rating", y="length", kind='box') # ploting box plot
g.fig.set_size_inches(5, 5) # sixe of plot
# Adding x and y axis labels
plt.xlabel('rating') 
plt.ylabel('Length')
# Out:
# C:\Users\prave\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(-3.9305555555555554, 0.5, 'Length')

# %% [markdown]
# ## Pre-processing pipeline

# %%
# Importing Regex Package
import regex as re
# Defining a Function to Pull Words
def tokenize(description):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', description)

# %%
import nltk

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {"that'll", 'my', 'doesn', "aren't", 'any', 'm', 'an', 'not', 'most', 'each', 'only', "wasn't", 'haven', 'been', 'will', 'our', "didn't", 'very', 'on', 'hasn', "shouldn't", 'd', 'but', "don't", 'was', 'now', 'does', 'at', 'up', 'those', 'hadn', 'these', 'more', 'is', 'nor', 'or', 'his', 'how', 'when', 'shouldn', 'few', 'him', 'no', "mightn't", 'here', 'so', "mustn't", 'below', 'aren', 'by', 've', 'during', 'she', 'herself', 'that', 'having', 'needn', 'out', 't', 're', 'the', 'didn', "doesn't", 'i', 'isn', 'myself', 'from', 'you', 'ain', 'me', 'wasn', "you're", 'we', 'be', 'were', 'about', 'there', 'o', 'mightn', 'has', "you've", "won't", 'once', "needn't", 'such', 'yourself', 'just', 'did', 'own', 'in', 'who', 'being', 's', "you'd", 'between', 'don', 'against', 'then', 'a', 'am', 'have', 'do', 'ourselves', 'themselves', 'weren', 'to', 'where', 'himself', 'y', 'after', 'whom', 'while', "it's", 'why', 'he', "hasn't", 'theirs', 'they', "hadn't", 'over', 'above', 'under', "should've", "s
# ...

# %%
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {"that'll", 'my', 'doesn', "aren't", 'any', 'm', 'an', 'not', 'most', 'each', 'only', "wasn't", 'haven', 'been', 'will', 'our', "didn't", 'very', 'on', 'hasn', "shouldn't", 'd', 'but', "don't", 'was', 'now', 'does', 'at', 'up', 'those', 'hadn', 'these', 'more', 'is', 'nor', 'or', 'his', 'how', 'when', 'shouldn', 'few', 'him', 'no', "mightn't", 'here', 'so', "mustn't", 'below', 'aren', 'by', 've', 'during', 'she', 'herself', 'that', 'having', 'needn', 'out', 't', 're', 'the', 'didn', "doesn't", 'i', 'isn', 'myself', 'from', 'you', 'ain', 'me', 'wasn', "you're", 'we', 'be', 'were', 'about', 'there', 'o', 'mightn', 'has', "you've", "won't", 'once', "needn't", 'such', 'yourself', 'just', 'did', 'own', 'in', 'who', 'being', 's', "you'd", 'between', 'don', 'against', 'then', 'a', 'am', 'have', 'do', 'ourselves', 'themselves', 'weren', 'to', 'where', 'himself', 'y', 'after', 'whom', 'while', "it's", 'why', 'he', "hasn't", 'theirs', 'they', "hadn't", 'over', 'above', 'under', "should've", "s
# ...

# %% [markdown]
# ## Removing the Tokens

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# %% [markdown]
# ## Creating the Pipeline

# %%
# Creating a Pipeline
pipeline = [str.lower, tokenize, remove_stop]

# Defining a Function to Run the Pipeline
def prepare(description, pipeline):
    if isinstance(description, str):  # Check if description is a string
        tokens = description
        for fun in pipeline:
            tokens = fun(tokens)
        return tokens
    else:
        return []  # Return an empty list for non-string values

# %%
# Running the Pipeline
df['tokens'] = df['description'].apply(prepare, pipeline=pipeline)

# %%
#creating a New Column for the Number of Tokens
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#      show_id     type                    title         director  \
# 9663   s9664    movie      PRIDE OF THE BOWERY  JOSEPH H. LEWIS
# 9664   s9665  tv show            PLANET PATROL          UNKNOWN
# 9665   s9666    movie                  OUTPOST     STEVE BARKER
# 9666   s9667  tv show  MARADONA: BLESSED DREAM          UNKNOWN
# 9667   s9668    movie              HARRY BROWN    DANIEL BARBER
#
#                                                    cast  country date_added  \
# 9663                           Leo Gorcey, Bobby Jordan  unknown    unknown
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...  unknown    unknown
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...  unknown    unknown
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...  unknown    unknown
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...  unknown    unknown
#
#       release_year rating   duration                listed_in  \
# ...

# %% [markdown]
# ## Word Frequency Analysis

# %%
# importing a function Counter
from collections import Counter

# %%
# Printing the 5 Words Repeated the Most
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('life', 1444), ('one', 1219), ('new', 1097), ('world', 1060), ('love', 1030)]

# %%
# Creating a New Data Frame for Frequency Analysis 
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %%
# Sorting the freq_df based on Frequency
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#         freq
# token
# life    1444
# one     1219
# new     1097
# world   1060
# love    1030
# story    994
# family   921
# young    913
# two      822
# man      746

# %%
# Printing the Statistical Data of Frequency
freq_df.describe()
# Out:
#                freq
# count  30856.000000
# mean       7.797187
# std       31.465242
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max     1444.000000

# %% [markdown]
# ## Bar-Graph

# %%
# Plotting a bar graph for most frequent words 
ax = freq_df.head(10).plot(kind='barh', width=0.95, figsize=(8,6))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %% [markdown]
# ## Word-Cloud

# %%
# WordCloud visualization of Frequency
wc = WordCloud(background_color='black', width = 300, height=300, max_words=150, margin=2)  #BackGround Colour
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (10, 10), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
