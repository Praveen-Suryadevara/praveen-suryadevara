# %%
import pandas as pd #Importing pandas as pd
file="C:/Users/prave/Downloads/un-general-debates-blueprint.csv"
df=pd.read_csv(file) #R"C:\Users\prave\Downloads\un-general-debates-blueprint.csv"eading the CSV File
df.head(20) #printing the first 20 rows
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %% [markdown]
# ## Getting the Stop-Words

# %%
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'re', "aren't", 'here', 'whom', 'itself', 'aren', 'during', 'they', 'than', 'own', 'too', 'ourselves', 'all', "you're", 'been', 'by', "haven't", 'under', 'which', 'about', 'above', 'from', 'just', 'is', 'further', "isn't", 'yourselves', 'off', 'didn', "didn't", 'then', "you've", 'this', 'after', 'while', 'am', 'both', "needn't", 'our', 'their', 'these', 'because', 'those', 'why', 'what', 'haven', 'be', 'against', "wasn't", 'has', "weren't", 'my', 'and', 'his', "don't", 'herself', 'hers', 'only', "she's", 'before', "doesn't", 'won', 'me', 'who', 'at', 've', 'were', 'how', 's', 'needn', 'shouldn', 'up', 'd', 'any', 'but', 'that', 'them', "mightn't", 'until', 'wasn', 'isn', 'myself', "it's", 'he', 'below', 'being', 'not', 'mustn', 'shan', 'y', 'weren', 'the', 'm', 'some', 'o', 'an', "hasn't", 'ours', 'or', 'through', 'on', 'hasn', 'it', 'does', 'each', 'same', 'can', 'mightn', 'him', "that'll", "shouldn't", 'if', 'again', 'we', 'are', "won't", 'i', 'll', "wouldn't", 'other', 'do', 'few
# ...

# %% [markdown]
# ## Pre-Processing pipeline

# %%
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
        return tokens
    df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
from collections import Counter
counter = Counter()
df['tokens'].map(counter.update)
freq_df = pd.DataFrame.from_dict(counter, orient='index',
                                 columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name ='token’
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#   Cell In[8], line 7
#     freq_df.index.name ='token’
#                         ^
# SyntaxError: unterminated string literal (detected at line 7)
